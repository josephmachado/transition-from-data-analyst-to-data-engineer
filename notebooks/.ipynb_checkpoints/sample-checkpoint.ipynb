# %% [markdown]
# ## Create TPCH Data

# %%
# %%capture
# %%bash
python ./generate_data.py

# %%
# %sql duckdb:///:memory:
# Out:
# Connecting to 'duckdb:///:memory:'

# %%
# %%sql
# select 1
# Out:
# Running query in 'duckdb:///:memory:'
#    1
# 0  1
